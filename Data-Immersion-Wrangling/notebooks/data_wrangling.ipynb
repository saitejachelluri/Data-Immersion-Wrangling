# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\sai teja\Downloads\superstore.csv.zip",encoding='latin1')

df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
# Row ID           9994 non-null int64
# Order ID         9994 non-null object
# Order Date       9994 non-null object
# Ship Date        9994 non-null object
# Ship Mode        9994 non-null object
# Customer ID      9994 non-null object
# Customer Name    9994 non-null object
# Segment          9994 non-null object
# Country          9994 non-null object
# City             9994 non-null object
# State            9994 non-null object
# Postal Code      9994 non-null int64
# Region           9994 non-null object
# Product ID       9994 non-null object
# Category         9994 non-null object
# Sub-Category     9994 non-null object
# Product Name     9994 non-null object
# Sales            9994 non-null float64
# Quantity         9994 non-null int64
# Discount         9994 non-null float64
# Profit           9994 non-null float64
# dtypes: float64(3), int64(3), object(15)
# ...

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))

sns.heatmap(df.isnull(), cbar=False)

plt.title("Missing Values Heatmap")

plt.show()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %% [markdown]
# # Data Dictionary
#
# | Column Name | Description |
# |-------------|-------------|
# | Row ID | Unique row identifier |
# | Order ID | Unique identifier for each order |
# | Order Date | Date when the order was placed |
# | Ship Date | Date when the order was shipped |
# | Ship Mode | Shipping method used |
# | Customer ID | Unique customer identifier |
# | Customer Name | Name of the customer |
# | Segment | Customer segment |
# | Country | Customer country |
# | City | Customer city |
# | State | Customer state |
# | Postal Code | Area postal code |
# | Region | Sales region |
# | Product ID | Unique product identifier |
# | Category | Product category |
# | Sub-Category | Product sub-category |
# | Product Name | Name of the product |
# | Sales | Total sales amount |
# | Quantity | Number of items sold |
# | Discount | Discount applied |
# | Profit | Profit earned from the order |

# %% [markdown]
# ## Missing Value Analysis
#
# After performing data quality assessment using `df.isnull().sum()`,
# no missing values were identified in the dataset.
#
# This indicates that the dataset is complete and well-structured
# for further analysis and transformation.

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Duplicate Value Analysis
#
# The dataset was checked for duplicate records using
# `df.duplicated().sum()`.
#
# No duplicate rows were found in the dataset, indicating
# good data consistency and integrity.

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])

df['Ship Date'] = pd.to_datetime(df['Ship Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
# Row ID           9994 non-null int64
# Order ID         9994 non-null object
# Order Date       9994 non-null datetime64[ns]
# Ship Date        9994 non-null datetime64[ns]
# Ship Mode        9994 non-null object
# Customer ID      9994 non-null object
# Customer Name    9994 non-null object
# Segment          9994 non-null object
# Country          9994 non-null object
# City             9994 non-null object
# State            9994 non-null object
# Postal Code      9994 non-null int64
# Region           9994 non-null object
# Product ID       9994 non-null object
# Category         9994 non-null object
# Sub-Category     9994 non-null object
# Product Name     9994 non-null object
# Sales            9994 non-null float64
# Quantity         9994 non-null int64
# Discount         9994 non-null float64
# Profit           9994 non-null float64
# ...

# %%
df['Order Year'] = df['Order Date'].dt.year

df['Order Month'] = df['Order Date'].dt.month

df['Order Day'] = df['Order Date'].dt.day

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))

sns.boxplot(x=df['Sales'])

plt.title("Outlier Detection in Sales")

plt.show()

# %% [markdown]
# ## Outlier Detection
#
# Outlier analysis was performed using a boxplot on the `Sales`
# column to identify extreme values and understand data distribution.
#
# The visualization helps detect unusually high or low sales values
# that may influence analytical results.

# %%
plt.figure(figsize=(10,6))

corr = df.corr()

sns.heatmap(corr, annot=True)

plt.title("Correlation Matrix")

plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 24 columns):
# Row ID           9994 non-null int64
# Order ID         9994 non-null object
# Order Date       9994 non-null datetime64[ns]
# Ship Date        9994 non-null datetime64[ns]
# Ship Mode        9994 non-null object
# Customer ID      9994 non-null object
# Customer Name    9994 non-null object
# Segment          9994 non-null object
# Country          9994 non-null object
# City             9994 non-null object
# State            9994 non-null object
# Postal Code      9994 non-null int64
# Region           9994 non-null object
# Product ID       9994 non-null object
# Category         9994 non-null object
# Sub-Category     9994 non-null object
# Product Name     9994 non-null object
# Sales            9994 non-null float64
# Quantity         9994 non-null int64
# Discount         9994 non-null float64
# Profit           9994 non-null float64
# ...

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# Order Year       0
# Order Month      0
# Order Day        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Final Data Validation
#
# After completing data cleaning and transformation processes,
# the dataset was validated to ensure:
#
# - No missing values
# - No duplicate records
# - Correct data types
# - Consistent formatting
#
# The dataset is now analysis-ready and suitable for further
# business intelligence and analytical tasks.

# %%
df.to_csv(r"C:\Users\sai teja\Downloads\superstore.csv.zip", index=False)

# %%
plt.figure(figsize=(10,5))

sns.distplot(df['Sales'])

plt.title("Sales Distribution")

plt.xlabel("Sales")

plt.ylabel("Density")

plt.show()

# %% [markdown]
# ## Sales Distribution Analysis
#
# A distribution plot was created to analyze the spread and
# frequency of sales values within the dataset.
#
# The visualization helps understand business trends,
# sales concentration, and data variability.

# %% [markdown]
# # Data Immersion & Wrangling Project
#
# ## Project Overview
# This project focuses on performing data immersion,
# data quality assessment, data cleaning, and transformation
# on a retail sales dataset.
#
# The objective is to prepare a clean and analysis-ready dataset
# for further business intelligence and analytical tasks.
#
# ---
#
# ## Objectives
# - Understand raw dataset structure
# - Assess data quality issues
# - Handle missing values and duplicates
# - Standardize data formats
# - Perform feature engineering
# - Generate analytical visualizations
#
# ---
#
# ## Technologies Used
# - Python
# - Pandas
# - NumPy
# - Matplotlib
# - Seaborn
# - Jupyter Notebook
#
# ---
#
# ## Data Cleaning Steps
# - Missing value analysis
# - Duplicate record validation
# - Data type conversion
# - Date transformation
# - Feature engineering
# - Outlier detection
# - Correlation analysis
#
# ---
#
# ## Features Engineered
# - Order Year
# - Order Month
# - Order Day
#
# ---
#
# ## Final Outcome
# The dataset was successfully cleaned, transformed,
# and validated for analytical purposes.
#
# ---
#
# ## Author
# Sai Teja
